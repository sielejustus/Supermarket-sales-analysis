# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('supermarket_sales.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Date'] = df['Date'].astype(str)

# %%
df['Date']
# Out:
# 0      2019-01-05
# 1      2019-03-08
# 2      2019-03-03
# 3      2019-01-27
# 4      2019-02-08
#           ...
# 995    2019-01-29
# 996    2019-03-02
# 997    2019-02-09
# 998    2019-02-22
# 999    2019-02-18
# Name: Date, Length: 1000, dtype: object

# %%
df['Month'] = df['Date'].apply(lambda x : x.split('-')[1])

# %%
df['Date'] = df['Date'].astype(str)

# %%
df['Day'] = df['Date'].apply(lambda x : x.split('-')[2])

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# Month                      0
# Day                        0
# dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  2019-01-05  13:08      Ewallet  522.83                 4.761905
# 1  2019-03-08  10:29         Cash   76.40                 4.761905
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Month', 'Day'],
#       dtype='object')

# %%
city_total = df.groupby(['Branch', 'City'])['Total','Tax 5%','gross income'].sum()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/913543372.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   city_total = df.groupby(['Branch', 'City'])['Total','Tax 5%','gross income'].sum()

# %%
city_total
# Out:
#                         Total     Tax 5%  gross income
# Branch City
# A      Yangon     106200.3705  5057.1605     5057.1605
# B      Mandalay   106197.6720  5057.0320     5057.0320
# C      Naypyitaw  110568.7065  5265.1765     5265.1765

# %%
city_total_monthly = df.groupby(['Month', 'City'])['Total','Tax 5%','gross income'].sum()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/3078479058.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   city_total_monthly = df.groupby(['Month', 'City'])['Total','Tax 5%','gross income'].sum()

# %%
df.groupby(['Month'])['Tax 5%','Total', 'gross income'].sum().sort_values(by='Total',ascending=False)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/939559075.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Month'])['Tax 5%','Total', 'gross income'].sum().sort_values(by='Total',ascending=False)
#          Tax 5%       Total  gross income
# Month
# 01     5537.708  116291.868      5537.708
# 03     5212.167  109455.507      5212.167
# 02     4629.494   97219.374      4629.494

# %%
city_total_monthly
# Out:
#                       Total     Tax 5%  gross income
# Month City
# 01    Mandalay   37176.0585  1770.2885     1770.2885
#       Naypyitaw  40434.6810  1925.4610     1925.4610
#       Yangon     38681.1285  1841.9585     1841.9585
# 02    Mandalay   34424.2710  1639.2510     1639.2510
#       Naypyitaw  32934.9825  1568.3325     1568.3325
#       Yangon     29860.1205  1421.9105     1421.9105
# 03    Mandalay   34597.3425  1647.4925     1647.4925
#       Naypyitaw  37199.0430  1771.3830     1771.3830
#       Yangon     37659.1215  1793.2915     1793.2915

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Month', 'Day'],
#       dtype='object')

# %%
df.groupby(['Product line'])['Gender'].value_counts().to_frame()
# Out:
#                                Gender
# Product line           Gender
# Electronic accessories Male        86
#                        Female      84
# Fashion accessories    Female      96
#                        Male        82
# Food and beverages     Female      90
#                        Male        84
# Health and beauty      Male        88
#                        Female      64
# Home and lifestyle     Male        81
#                        Female      79
# Sports and travel      Female      88
#                        Male        78

# %%
df.groupby(['Product line'])['Tax 5%', 'gross income'].sum().sort_values(by='gross income', ascending=False)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/169474370.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Product line'])['Tax 5%', 'gross income'].sum().sort_values(by='gross income', ascending=False)
#                            Tax 5%  gross income
# Product line
# Food and beverages      2673.5640     2673.5640
# Sports and travel       2624.8965     2624.8965
# Electronic accessories  2587.5015     2587.5015
# Fashion accessories     2585.9950     2585.9950
# Home and lifestyle      2564.8530     2564.8530
# Health and beauty       2342.5590     2342.5590

# %%
df.groupby(['City','Product line'])['Tax 5%', 'gross income'].sum()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/3544652190.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['City','Product line'])['Tax 5%', 'gross income'].sum()
#                                      Tax 5%  gross income
# City      Product line
# Mandalay  Electronic accessories   811.9735      811.9735
#           Fashion accessories      781.5865      781.5865
#           Food and beverages       724.5185      724.5185
#           Health and beauty        951.4600      951.4600
#           Home and lifestyle       835.6745      835.6745
#           Sports and travel        951.8190      951.8190
# Naypyitaw Electronic accessories   903.2845      903.2845
#           Fashion accessories     1026.6700     1026.6700
#           Food and beverages      1131.7550     1131.7550
#           Health and beauty        791.2060      791.2060
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Month', 'Day'],
#       dtype='object')

# %%
df.groupby(['City','Product line'])['Rating'].sum().to_frame()
# Out:
#                                   Rating
# City      Product line
# Mandalay  Electronic accessories   391.4
#           Fashion accessories      416.8
#           Food and beverages       349.7
#           Health and beauty        376.3
#           Home and lifestyle       325.8
#           Sports and travel        403.6
# Naypyitaw Electronic accessories   371.1
#           Fashion accessories      483.6
#           Food and beverages       467.3
#           Health and beauty        363.9
#           Home and lifestyle       317.7
#           Sports and travel        316.3
# Yangon    Electronic accessories   414.7
#           Fashion accessories      350.8
#           Food and beverages       420.7
#           Health and beauty        324.3
#           Home and lifestyle       450.5
#           Sports and travel        428.2

# %%
df.Payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
df.groupby(['Payment'])['Tax 5%','Total','gross income'].sum().sort_values(by='Total', ascending=False)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/1756752356.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Payment'])['Tax 5%','Total','gross income'].sum().sort_values(by='Total', ascending=False)
#                Tax 5%       Total  gross income
# Payment
# Cash         5343.170  112206.570      5343.170
# Ewallet      5237.767  109993.107      5237.767
# Credit card  4798.432  100767.072      4798.432

# %%
df.groupby(['Customer type'])['Tax 5%','Total','gross income'].sum()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12716/2111395922.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Customer type'])['Tax 5%','Total','gross income'].sum()
#                  Tax 5%       Total  gross income
# Customer type
# Member         7820.164  164223.444      7820.164
# Normal         7559.205  158743.305      7559.205

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Month', 'Day'],
#       dtype='object')
